# %%
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_json('results/compare.json')
actual_diff = []
predicted_diff = []

for i in df.columns:
    actual_diff.append(df[i]["actual_diff"])
    predicted_diff.append(df[i]["influence"])
    
plt.scatter(actual_diff, predicted_diff)
