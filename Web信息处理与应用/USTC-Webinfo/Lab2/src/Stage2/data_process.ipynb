# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

embedding = [16, 24, 32, 48, 64]
recall5 = [0.06259959936141968, 0.06288766860961914, 0.05901442468166351, 0.06981351971626282, 0.06450024247169495]
ndcg5 = [0.2902551477361832, 0.3004784621578108, 0.29007359782789105, 0.316093866910746, 0.29935083963597536]
recall10 = [0.10716267675161362, 0.10908342152833939, 0.10795808583498001, 0.11553004384040833, 0.11316339671611786]
ndcg10 = [0.2673719772479413, 0.2751890069963962, 0.2715199083871477, 0.28812096127439535, 0.2770698721009129]
plt.plot(embedding, recall5, 'o-',color = 'g', label='recall@5', linewidth = '1.5')
plt.title('change embedding dim')
plt.xlabel('embedding dim')
# plt.ylabel('recall@5')
# x_ticks = np.arange(-6, 7, 1)  #坐标轴精度设置
# plt.xticks(x_ticks)
y_ticks = np.arange(0.056, 0.072, 0.001)
plt.yticks(y_ticks)
plt.legend(loc = "best")  #图例

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

embedding = [16, 24, 32, 48, 64]
recall5 = [0.06259959936141968, 0.06288766860961914, 0.05901442468166351, 0.06981351971626282, 0.06450024247169495]
ndcg5 = [0.2902551477361832, 0.3004784621578108, 0.29007359782789105, 0.316093866910746, 0.29935083963597536]
recall10 = [0.10716267675161362, 0.10908342152833939, 0.10795808583498001, 0.11553004384040833, 0.11316339671611786]
ndcg10 = [0.2673719772479413, 0.2751890069963962, 0.2715199083871477, 0.28812096127439535, 0.2770698721009129]
plt.plot(embedding, recall10, 'o-',color = 'r', label='recall@10', linewidth = '1.5')
plt.title('change embedding dim')
plt.xlabel('embedding dim')
# plt.ylabel('recall@5')
# x_ticks = np.arange(-6, 7, 1)  #坐标轴精度设置
# plt.xticks(x_ticks)
y_ticks = np.arange(0.106, 0.118, 0.001)
plt.yticks(y_ticks)
plt.legend(loc = "best")  #图例

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

embedding = [16, 24, 32, 48, 64]
recall5 = [0.06259959936141968, 0.06288766860961914, 0.05901442468166351, 0.06981351971626282, 0.06450024247169495]
ndcg5 = [0.2902551477361832, 0.3004784621578108, 0.29007359782789105, 0.316093866910746, 0.29935083963597536]
recall10 = [0.10716267675161362, 0.10908342152833939, 0.10795808583498001, 0.11553004384040833, 0.11316339671611786]
ndcg10 = [0.2673719772479413, 0.2751890069963962, 0.2715199083871477, 0.28812096127439535, 0.2770698721009129]
plt.plot(embedding, ndcg5, 'o-',color = 'y', label='ndcg@5', linewidth = '1.5')
plt.title('change embedding dim')
plt.xlabel('embedding dim')
# plt.ylabel('recall@5')
# x_ticks = np.arange(-6, 7, 1)  #坐标轴精度设置
# plt.xticks(x_ticks)
y_ticks = np.arange(0.288, 0.318, 0.002)
plt.yticks(y_ticks)
plt.legend(loc = "best")  #图例

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

embedding = [16, 24, 32, 48, 64]
recall5 = [0.06259959936141968, 0.06288766860961914, 0.05901442468166351, 0.06981351971626282, 0.06450024247169495]
ndcg5 = [0.2902551477361832, 0.3004784621578108, 0.29007359782789105, 0.316093866910746, 0.29935083963597536]
recall10 = [0.10716267675161362, 0.10908342152833939, 0.10795808583498001, 0.11553004384040833, 0.11316339671611786]
ndcg10 = [0.2673719772479413, 0.2751890069963962, 0.2715199083871477, 0.28812096127439535, 0.2770698721009129]
plt.plot(embedding, ndcg10, 'o-',color = 'b', label='ndcg@10', linewidth = '1.5')
plt.title('change embedding dim')
plt.xlabel('embedding dim')
# plt.ylabel('recall@5')
# x_ticks = np.arange(-6, 7, 1)  #坐标轴精度设置
# plt.xticks(x_ticks)
y_ticks = np.arange(0.264, 0.290, 0.002)
plt.yticks(y_ticks)
plt.legend(loc = "best")  #图例

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# lr = [1e-2, 1e-4, 1e-3]
l2 = [1e-5, 5e-5, 1e-4, 2e-4, 1e-3]
recall5 = [0.0473967082798481, 0.04487615078687668, 0.04856427386403084, 0.04939430579543114, 0.048564810305833817]
ndcg5 = [0.21766786872658, 0.22169987020399695, 0.21885150128258432, 0.21946322294485712, 0.23149763769206932]
recall10 = [0.08682618290185928, 0.08643312007188797, 0.0852237194776535, 0.08567018806934357, 0.08650258928537369]
ndcg10 = [0.2095036372539714, 0.21382904661350363, 0.20783945838864046, 0.2108565201548943, 0.21978766557164547]

recall5_ = [0.06709321588277817, 0.06742090731859207, 0.06681724637746811, 0.06640595197677612, 0.06631084531545639]
ndcg5_ = [0.31273807477115506, 0.31416836884433874, 0.31356414649312625, 0.3130567034530482, 0.31410488137004705]
recall10_ = [0.11311972886323929, 0.1140090599656105, 0.11515439301729202, 0.11465360224246979, 0.11604977399110794]
ndcg10_ = [0.28295846050573537, 0.2839137713227252, 0.2857412389193274, 0.28430547617385377, 0.28715764718383086]

recall5__ = [0.05848788097500801, 0.058790989220142365, 0.0653, 0.058896180242300034, 0.060105230659246445]
ndcg5__ = [0.28840813576618834, 0.2899607627069269, 0.3001, 0.28929728461365145, 0.29834926601634765]
recall10__ = [0.10806863754987717, 0.1082841008901596, 0.1105, 0.10782577842473984, 0.10570518672466278]
ndcg10__ = [0.27135593842512085, 0.2721903010037336, 0.2762, 0.2718796186262877, 0.2733219425264798]
plt.plot(l2, recall5, 'o-',color = 'b', label='lr=1e-2', linewidth = '1.5')
plt.plot(l2, recall5_, 'o-',color = 'r', label='lr=1e-4', linewidth = '1.5')
plt.plot(l2, recall5__, 'o-',color = 'g', label='lr=1e-3', linewidth = '1.5')
plt.title('change kg_l2loss_lambda  cf_l2loss_lambda')
plt.xlabel('kg_l2loss_lambda=cf_l2loss_lambda')
plt.ylabel('recall@5')
# x_ticks = np.arange(-6, 7, 1)  #坐标轴精度设置
# plt.xticks(x_ticks)
y_ticks = np.arange(0.0430, 0.0676, 0.002)
plt.yticks(y_ticks)
plt.legend(loc = "best")  #图例

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# lr = [1e-2, 1e-4, 1e-3]
l2 = [1e-5, 5e-5, 1e-4, 2e-4, 1e-3]
recall5 = [0.0473967082798481, 0.04487615078687668, 0.04856427386403084, 0.04939430579543114, 0.048564810305833817]
ndcg5 = [0.21766786872658, 0.22169987020399695, 0.21885150128258432, 0.21946322294485712, 0.23149763769206932]
recall10 = [0.08682618290185928, 0.08643312007188797, 0.0852237194776535, 0.08567018806934357, 0.08650258928537369]
ndcg10 = [0.2095036372539714, 0.21382904661350363, 0.20783945838864046, 0.2108565201548943, 0.21978766557164547]

recall5_ = [0.06709321588277817, 0.06742090731859207, 0.06681724637746811, 0.06640595197677612, 0.06631084531545639]
ndcg5_ = [0.31273807477115506, 0.31416836884433874, 0.31356414649312625, 0.3130567034530482, 0.31410488137004705]
recall10_ = [0.11311972886323929, 0.1140090599656105, 0.11515439301729202, 0.11465360224246979, 0.11604977399110794]
ndcg10_ = [0.28295846050573537, 0.2839137713227252, 0.2857412389193274, 0.28430547617385377, 0.28715764718383086]

recall5__ = [0.05848788097500801, 0.058790989220142365, 0.0653, 0.058896180242300034, 0.060105230659246445]
ndcg5__ = [0.28840813576618834, 0.2899607627069269, 0.3001, 0.28929728461365145, 0.29834926601634765]
recall10__ = [0.10806863754987717, 0.1082841008901596, 0.1105, 0.10782577842473984, 0.10570518672466278]
ndcg10__ = [0.27135593842512085, 0.2721903010037336, 0.2762, 0.2718796186262877, 0.2733219425264798]
plt.plot(l2, recall10, 'o-',color = 'b', label='lr=1e-2', linewidth = '1.5')
plt.plot(l2, recall10_, 'o-',color = 'r', label='lr=1e-4', linewidth = '1.5')
plt.plot(l2, recall10__, 'o-',color = 'g', label='lr=1e-3', linewidth = '1.5')
plt.title('change kg_l2loss_lambda  cf_l2loss_lambda')
plt.xlabel('kg_l2loss_lambda=cf_l2loss_lambda')
plt.ylabel('recall@10')
# x_ticks = np.arange(-6, 7, 1)  #坐标轴精度设置
# plt.xticks(x_ticks)
y_ticks = np.arange(0.0850, 0.1166, 0.002)
plt.yticks(y_ticks)
plt.legend(loc = "best")  #图例

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# lr = [1e-2, 1e-4, 1e-3]
l2 = [1e-5, 5e-5, 1e-4, 2e-4, 1e-3]
recall5 = [0.0473967082798481, 0.04487615078687668, 0.04856427386403084, 0.04939430579543114, 0.048564810305833817]
ndcg5 = [0.21766786872658, 0.22169987020399695, 0.21885150128258432, 0.21946322294485712, 0.23149763769206932]
recall10 = [0.08682618290185928, 0.08643312007188797, 0.0852237194776535, 0.08567018806934357, 0.08650258928537369]
ndcg10 = [0.2095036372539714, 0.21382904661350363, 0.20783945838864046, 0.2108565201548943, 0.21978766557164547]

recall5_ = [0.06709321588277817, 0.06742090731859207, 0.06681724637746811, 0.06640595197677612, 0.06631084531545639]
ndcg5_ = [0.31273807477115506, 0.31416836884433874, 0.31356414649312625, 0.3130567034530482, 0.31410488137004705]
recall10_ = [0.11311972886323929, 0.1140090599656105, 0.11515439301729202, 0.11465360224246979, 0.11604977399110794]
ndcg10_ = [0.28295846050573537, 0.2839137713227252, 0.2857412389193274, 0.28430547617385377, 0.28715764718383086]

recall5__ = [0.05848788097500801, 0.058790989220142365, 0.0653, 0.058896180242300034, 0.060105230659246445]
ndcg5__ = [0.28840813576618834, 0.2899607627069269, 0.3001, 0.28929728461365145, 0.29834926601634765]
recall10__ = [0.10806863754987717, 0.1082841008901596, 0.1105, 0.10782577842473984, 0.10570518672466278]
ndcg10__ = [0.27135593842512085, 0.2721903010037336, 0.2762, 0.2718796186262877, 0.2733219425264798]
plt.plot(l2, ndcg5, 'o-',color = 'b', label='lr=1e-2', linewidth = '1.5')
plt.plot(l2, ndcg5_, 'o-',color = 'r', label='lr=1e-4', linewidth = '1.5')
plt.plot(l2, ndcg5__, 'o-',color = 'g', label='lr=1e-3', linewidth = '1.5')
plt.title('change kg_l2loss_lambda  cf_l2loss_lambda')
plt.xlabel('kg_l2loss_lambda=cf_l2loss_lambda')
plt.ylabel('ndcg@5')
# x_ticks = np.arange(-6, 7, 1)  #坐标轴精度设置
# plt.xticks(x_ticks)
y_ticks = np.arange(0.217, 0.315, 0.005)
plt.yticks(y_ticks)
plt.legend(loc = "best")  #图例

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# lr = [1e-2, 1e-4, 1e-3]
l2 = [1e-5, 5e-5, 1e-4, 2e-4, 1e-3]
recall5 = [0.0473967082798481, 0.04487615078687668, 0.04856427386403084, 0.04939430579543114, 0.048564810305833817]
ndcg5 = [0.21766786872658, 0.22169987020399695, 0.21885150128258432, 0.21946322294485712, 0.23149763769206932]
recall10 = [0.08682618290185928, 0.08643312007188797, 0.0852237194776535, 0.08567018806934357, 0.08650258928537369]
ndcg10 = [0.2095036372539714, 0.21382904661350363, 0.20783945838864046, 0.2108565201548943, 0.21978766557164547]

recall5_ = [0.06709321588277817, 0.06742090731859207, 0.06681724637746811, 0.06640595197677612, 0.06631084531545639]
ndcg5_ = [0.31273807477115506, 0.31416836884433874, 0.31356414649312625, 0.3130567034530482, 0.31410488137004705]
recall10_ = [0.11311972886323929, 0.1140090599656105, 0.11515439301729202, 0.11465360224246979, 0.11604977399110794]
ndcg10_ = [0.28295846050573537, 0.2839137713227252, 0.2857412389193274, 0.28430547617385377, 0.28715764718383086]

recall5__ = [0.05848788097500801, 0.058790989220142365, 0.0653, 0.058896180242300034, 0.060105230659246445]
ndcg5__ = [0.28840813576618834, 0.2899607627069269, 0.3001, 0.28929728461365145, 0.29834926601634765]
recall10__ = [0.10806863754987717, 0.1082841008901596, 0.1105, 0.10782577842473984, 0.10570518672466278]
ndcg10__ = [0.27135593842512085, 0.2721903010037336, 0.2762, 0.2718796186262877, 0.2733219425264798]
plt.plot(l2, ndcg10, 'o-',color = 'b', label='lr=1e-2', linewidth = '1.5')
plt.plot(l2, ndcg10_, 'o-',color = 'r', label='lr=1e-4', linewidth = '1.5')
plt.plot(l2, ndcg10__, 'o-',color = 'g', label='lr=1e-3', linewidth = '1.5')
plt.title('change kg_l2loss_lambda  cf_l2loss_lambda')
plt.xlabel('kg_l2loss_lambda=cf_l2loss_lambda')
plt.ylabel('ndcg@10')
# x_ticks = np.arange(-6, 7, 1)  #坐标轴精度设置
# plt.xticks(x_ticks)
y_ticks = np.arange(0.207, 0.288, 0.005)
plt.yticks(y_ticks)
plt.legend(loc = "best")  #图例
