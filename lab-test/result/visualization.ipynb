# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10, 8))
plt.title(
    "Train on inputs(148000 data points)", loc="center", fontweight="bold", fontsize=18
)
plt.xlabel("K", loc="center", fontweight="bold", fontsize=18)
plt.ylabel("HR@K", loc="center", fontweight="bold", fontsize=18)
plt.bar(
    [i for i in range(5)],
    [0.0242, 0.034, 0.0352, 0.0368, 0.039],
    label="Yes",
    width=0.2,
    color="#f9766e",
    edgecolor="k",
    zorder=2,
)
plt.bar(
    [i + 0.2 for i in range(5)],
    [0.0206, 0.03, 0.0316, 0.0322, 0.0334],
    label="No",
    width=0.2,
    color="#00bfc4",
    edgecolor="k",
    zorder=2,
    hatch="/",
)
plt.xticks(
    [i + 0.1 for i in range(5)],
    ["1", "3", "5", "10", "20"],
    fontweight="bold",
    fontsize=18,
)
plt.yticks(fontweight="bold", fontsize=18)
plt.legend(frameon=False, loc="best", fontsize=14)
for a, b, i in zip(
    [0.0242, 0.034, 0.0352, 0.0368, 0.039],
    [0.0206, 0.03, 0.0316, 0.0322, 0.0334],
    range(5),
):
    plt.text(i, a, str(a), ha="center", va="bottom", fontsize=12, fontweight="bold")
    plt.text(
        i + 0.2, b, str(b), ha="center", va="bottom", fontsize=12, fontweight="bold"
    )
plt.grid(ls="--", alpha=0.8)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["left"].set_linestyle("-")
plt.gca().spines["left"].set_linewidth(2.5)
plt.gca().spines["bottom"].set_linestyle("-")
plt.gca().spines["bottom"].set_linewidth(2.5)
plt.tight_layout()
plt.show()
plt.clf()

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10, 8))
plt.title("Train dataset size", loc="center", fontweight="bold", fontsize=18)
plt.xlabel("K", loc="center", fontweight="bold", fontsize=18)
plt.ylabel("HR@K", loc="center", fontweight="bold", fontsize=18)
plt.xticks(
    [i + 1 for i in range(5)],
    ["1", "3", "5", "10", "20"],
    fontweight="bold",
    fontsize=18,
)
plt.yticks(fontweight="bold", fontsize=18)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.0058, 0.0098, 0.0114, 0.0126, 0.017],
    marker="o",
    markersize=12,
    color="#f9766e",
    linewidth=4,
)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.0152, 0.0226, 0.0236, 0.025, 0.0274],
    marker="*",
    markersize=12,
    color="#00bfc4",
    linewidth=4,
)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.0244, 0.0322, 0.033, 0.034, 0.036],
    marker="D",
    markersize=12,
    color="#9ACD32",
    linewidth=4,
)
legend_font = {
    "style": "normal",
    "size": 14,  # 字号
    "weight": "bold",  # 是否加粗，不加粗
}
plt.legend(
    ["1024points", "8092points", "65536points"],
    frameon=False,
    loc="best",
    prop=legend_font,
)
plt.grid(ls="--", alpha=0.8)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["left"].set_linestyle("-")
plt.gca().spines["left"].set_linewidth(2.5)
plt.gca().spines["bottom"].set_linestyle("-")
plt.gca().spines["bottom"].set_linewidth(2.5)
plt.tight_layout()
plt.show()
plt.clf()

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10, 8))
plt.title(
    "Learning Rate(148480 data points)", loc="center", fontweight="bold", fontsize=18
)
plt.xlabel("K", loc="center", fontweight="bold", fontsize=18)
plt.ylabel("HR@K", loc="center", fontweight="bold", fontsize=18)
plt.xticks(
    [i + 1 for i in range(5)],
    ["1", "3", "5", "10", "20"],
    fontweight="bold",
    fontsize=18,
)
plt.yticks(fontweight="bold", fontsize=18)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.0116, 0.0222, 0.024, 0.025, 0.027],
    marker="o",
    markersize=12,
    color="#f9766e",
    linewidth=4,
)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.024, 0.031, 0.0318, 0.0344, 0.0358],
    marker="*",
    markersize=12,
    color="#00bfc4",
    linewidth=4,
)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.0228, 0.0284, 0.0292, 0.03, 0.0318],
    marker="D",
    markersize=12,
    color="#9ACD32",
    linewidth=4,
)
legend_font = {
    "style": "normal",
    "size": 14,  # 字号
    "weight": "bold",  # 是否加粗，不加粗
}
plt.legend(
    ["lr=3e-5, constant", "lr=1e-4, constant", "lr=3e-4, constant"],
    frameon=False,
    loc="best",
    prop=legend_font,
)
plt.grid(ls="--", alpha=0.8)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["left"].set_linestyle("-")
plt.gca().spines["left"].set_linewidth(2.5)
plt.gca().spines["bottom"].set_linestyle("-")
plt.gca().spines["bottom"].set_linewidth(2.5)
plt.tight_layout()
plt.show()
plt.clf()

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10, 8))
plt.title(
    "Padding Side(140000 data points)", loc="center", fontweight="bold", fontsize=18
)
plt.xlabel("K", loc="center", fontweight="bold", fontsize=18)
plt.ylabel("HR@K", loc="center", fontweight="bold", fontsize=18)
plt.bar(
    [i for i in range(5)],
    [0.0226, 0.0306, 0.0322, 0.0332, 0.0354],
    label="Right",
    width=0.2,
    color="#f9766e",
    edgecolor="k",
    zorder=2,
)
plt.bar(
    [i + 0.2 for i in range(5)],
    [0.027, 0.0364, 0.0372, 0.0386, 0.041],
    label="Left",
    width=0.2,
    color="#00bfc4",
    edgecolor="k",
    zorder=2,
    hatch="/",
)
plt.xticks(
    [i + 0.1 for i in range(5)],
    ["1", "3", "5", "10", "20"],
    fontweight="bold",
    fontsize=18,
)
plt.yticks(fontweight="bold", fontsize=18)
legend_font = {
    "style": "normal",
    "size": 14,  # 字号
    "weight": "bold",  # 是否加粗，不加粗
}
plt.legend(frameon=False, loc="best", prop=legend_font)
for a, b, i in zip(
    [0.0226, 0.0306, 0.0322, 0.0332, 0.0354],
    [0.027, 0.0364, 0.0372, 0.0386, 0.041],
    range(5),
):
    plt.text(i, a, str(a), ha="center", va="bottom", fontsize=12, fontweight="bold")
    plt.text(
        i + 0.2, b, str(b), ha="center", va="bottom", fontsize=12, fontweight="bold"
    )
plt.grid(ls="--", alpha=0.8)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["left"].set_linestyle("-")
plt.gca().spines["left"].set_linewidth(2.5)
plt.gca().spines["bottom"].set_linestyle("-")
plt.gca().spines["bottom"].set_linewidth(2.5)
plt.tight_layout()
plt.show()
plt.clf()

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10, 8))
plt.title(
    "Number of Beams(test on sota ckpt)", loc="center", fontweight="bold", fontsize=18
)
plt.xlabel("K", loc="center", fontweight="bold", fontsize=18)
plt.ylabel("HR@K", loc="center", fontweight="bold", fontsize=18)
plt.xticks(
    [i + 1 for i in range(5)],
    ["1", "3", "5", "10", "20"],
    fontweight="bold",
    fontsize=18,
)
plt.yticks(fontweight="bold", fontsize=18)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.0256, 0.0346, 0.036, 0.0376, 0.04],
    marker="o",
    markersize=12,
    color="#f9766e",
    linewidth=4,
)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.0254, 0.0348, 0.036, 0.0372, 0.0398],
    marker="*",
    markersize=12,
    color="#00bfc4",
    linewidth=4,
)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.027, 0.0364, 0.0372, 0.0386, 0.041],
    marker="D",
    markersize=12,
    color="#9ACD32",
    linewidth=4,
)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.0254, 0.034, 0.0352, 0.0362, 0.0382],
    marker="h",
    markersize=12,
    color="#9370DB",
    linewidth=4,
)
plt.plot(
    [1, 2, 3, 4, 5],
    [0.0244, 0.0322, 0.033, 0.0344, 0.0358],
    marker="s",
    markersize=12,
    color="#FF8C00",
    linewidth=4,
)
legend_font = {
    "style": "normal",
    "size": 14,  # 字号
    "weight": "bold",  # 是否加粗，不加粗
}
plt.legend(
    ["num_beams=1", "num_beams=2", "num_beams=4", "num_beams=8", "num_beams=16"],
    frameon=False,
    loc="best",
    prop=legend_font,
)
plt.grid(ls="--", alpha=0.8)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["left"].set_linestyle("-")
plt.gca().spines["left"].set_linewidth(2.5)
plt.gca().spines["bottom"].set_linestyle("-")
plt.gca().spines["bottom"].set_linewidth(2.5)
plt.tight_layout()
plt.show()
plt.clf()
